# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import warnings
warnings.filterwarnings('ignore')
print("All libraries imported successfuly.")
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
# Out:
# All libraries imported successfuly.
# pandas version: 2.2.2
# numpy version: 2.0.2

# %%
from sklearn.datasets import load_iris

iris = load_iris()
print("Datasets loaded successfully!")
print(f"Datasets shape: {iris.data.shape}")
print(f"Features: {iris.feature_names}")
print(f"Target classes: {iris.target_names}")
# Out:
# Datasets loaded successfully!
# Datasets shape: (150, 4)
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target classes: ['setosa' 'versicolor' 'virginica']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]
print("First 5 rows of our datasets: ")
print(df.head())
print("n\Dataset info:")
print(df.info())
# Out:
# First 5 rows of our datasets:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# n\Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 6))

species_colors = {'setosa' : 'red', 'versicolor' : 'blue', 'virginica' : 'green'}

for species in df['species'].unique():
  species_data = df[df['species'] == species]
  plt.scatter(species_data['sepal length (cm)'],
              species_data['sepal width (cm)'],
              c=species_colors[species],
              label=species,
              alpha=0.7)

plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.title('Iris Dataser: Sepal Length vs Sepal Width')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
print("Congratulaions! You have created your first data virtualization")
# Out:
# Congratulaions! You have created your first data virtualization

# %% [markdown]
# The ragne for setosa

# %%
print("Basic Statistics for Iris Sataset:")
print("=" * 40)

species_means = df.groupby('species').mean()
print("nMean value by species:")
print(species_means)

species_count = df['species'].value_counts
print('nSamples per species:')
print(species_count)
# Out:
# Basic Statistics for Iris Sataset:
# ...
# nMean value by species:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
# nSamples per species:
# <bound method IndexOpsMixin.value_counts of 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object>

# %%
# Task 1: Create a simple calculation using NumPy
# Calculate the mean and standard deviation of sepal length
#species_mean = df.groupby('').mean()
sepal_lengths = df['sepal length (cm)']

# Your code here:
mean_sepal_length = np.mean(sepal_lengths)
std_sepal_length = np.std(sepal_lengths)

print(f"Mean sepal length: {mean_sepal_length:.2f} cm")
print(f"Standard deviation: {std_sepal_length:.2f} cm")

# Verification (don't modify)
assert isinstance(mean_sepal_length, (float, np.floating)), "Mean should be a number"
assert isinstance(std_sepal_length, (float, np.floating)), "Std should be a number"
print("✅ Task 1 completed successfully!")
# Out:
# Mean sepal length: 5.84 cm
# Standard deviation: 0.83 cm
# ✅ Task 1 completed successfully!

# %%
# Task 2: Create a simple bar chart showing species counts
species_counts = df['species'].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(species_counts.index, species_counts.values, color=['red', 'blue', 'green'])
plt.title('Number of Samples per Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

print(f"Species distribution: {dict(species_counts)}")
print("✅ Task 2 completed successfully!")
# Out:
# Species distribution: {'setosa': np.int64(50), 'versicolor': np.int64(50), 'virginica': np.int64(50)}
# ✅ Task 2 completed successfully!

# %%
df.shape
print("The number of samples is:", df.shape[0])
# Out:
# The number of samples is: 150

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# **Dataset Overview:**
# - Number of samples: [150]
# - Number of features: [4]
# - Number of classes: [3]
#
# **Key Findings from the Visualization:**
# 1. The Setosa flower forms a clearly seperated cluster from the other two species.
#
# 2. Versicolor and virginica mostly appear in the same range, making it difficult to classify them using only sepal widht and length.
#
# 3. Most flowers fall within a moderate range of sepal length and width.
#
# **Questions for Further Investigation:**
# - What other functions and abilities do these libraries have?
# - What is the best way to learn more about these libraries, and in which situations whould each one be the best choice?
#
# **Reflection:**
# *In 2-3 sentences, describe what you learned about using these tools.*
#
# In this lab, I learned how to call and use different Python libraries to make the project possible. I also learned how to load an existing dataset, identify the differnt classes, and create visual graphs to better understand the data.
# ---
# *Note: This is practice for documenting your machine learning projects professionally.*
